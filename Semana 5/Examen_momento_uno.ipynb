# %% [markdown]
# # Laboratorio 2

# %% [markdown]
# ## Desarrollo de una herramienta analítica usando paquetes especializados para análisis de datos en Python

# %% [markdown]
# Para el desarrollo de esta actividad puedes utilizar cualquier librería externa. Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito global de la actividad y puedas desarrollar tu solución apuntando a él desde el inicio.

# %% [markdown]
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
#
# 1. Identificar y abordar preguntas de negocio y de *analytics*.
# 2. Leer datos desde archivos y almacenarlos utilizando métodos de librerías especializadas.
# 3. Explorar, modificar, limpiar y unir objetos tablas de datos.
# 4. Implementar análisis combinando métricas descriptivas, visualización, filtrado y agrupación.
# 5. Implementar análisis basado en modelos estadísticos o de *machine learning*.

# %% [markdown]
# ##  Contexto: desigualdad y factores de éxito en pruebas Saber 11 en Colombia

# %% [markdown]
# El ICFES es el Instituto Colombiano para el Fomento de la Educación Superior y está adscrito al Ministerio de Educación a nivel nacional. Como parte de sus funciones, el ICFES administra las pruebas Saber 11, las cuales evalúan a todos los estudiantes del país al final de su educación secundaria. El examen contiene preguntas que evalúan una variedad de áreas del conocimiento (ej., matemáticas, física, inglés, etc.) y se lleva a cabo dos veces al año, ajustándose a los diferentes calendarios académicos que siguen las instituciones educativas. Al momento de inscribirse a las pruebas, los estudiantes diligencian un formulario que recoge información sociodemográfica y relacionada con la institución a la que pertenecen. El fin es obtener información con respecto al desempeño de los estudiantes en la prueba y de sus características.

# %% [markdown]
# Al igual que otros países de la región, Colombia tiene grandes retos en términos de desigualdad, particularmente en el contexto de educación primaria y secundaria. Por esta razón, para el Estado colombiano es muy valioso el amplio registro de datos que el ICFES genera alrededor de las pruebas Saber 11, pues con ellos se pueden generar análisis sobre la calidad de la educación en el país y eventualmente dar lugar a recomendaciones sobre políticas públicas. En particular, la problemática a abordar en este caso de estudio es la desigualdad y factores de éxito en las pruebas Saber 11.

# %% [markdown]
# Los objetivos de este caso de estudio son:
#
# * Entender el contenido de los archivos de datos proporcionados sobre las pruebas Saber 11, generar un reporte acerca de sus características principales y seleccionar las partes de dicho contenido que podrían ser relevantes para el análisis.
#
#
# * Identificar características de las variables de interés y relaciones entre ellas, por ejemplo, a través de agrupación, visualizaciones y estadísticas descriptivas.
#
#
# * Proponer un modelo que busque relacionar las variables de interés con el desempeño de los estudiantes y concluir acerca de los posibles hallazgos que se podrían reportar para el *stakeholder*.
#
#
# * Generar una herramienta que permita a un usuario interactuar con alguno de los parámetros del análisis realizado de forma relevante en el contexto del problema.

# %% [markdown]
# ## Fase 1: obtener e inspeccionar archivos

# %% [markdown]
# En esta fase te harás una idea general del contenido de los datos y generarás un reporte al respecto (ej., imprimiendo mensajes, presentando tablas de resumen, etc.). Además, seleccionarás un segmento de los datos que consideres útil para realizar tu análisis.

# %% [markdown]
# Pautas generales:
#
# * Utilizar una librería especializada para leer los archivos de datos y agregarlos según sea necesario (ej., utilizando los métodos `append` o `concat` si eliges cargarlos utilizando la librería `pandas`).
# * Inspeccionar el archivo a partir de sus encabezados, columnas y descripciones de las variables según su tipo (ej., numéricas, categóricas).
# * Declarar una estructura de datos (ej., una lista) para almacenar un subconjunto de variables que puedan ser relevantes para la problemática de interés.

# %% [markdown]
# Preguntas guía:
#
# * ¿Qué dimensiones tienen los datos?
# * ¿Con cuántos años y periodos de evaluación se cuenta?
# * ¿Cuáles variables pueden ser de interés para la problemática planteada?
# * ¿Qué porcentaje de datos faltantes o no válidos hay en las columnas de interés? ¿Qué planteas para manejarlos?

# %%
# Implementa tu respuesta en esta celda\

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


data = pd.read_csv("Saber_11°_2020-2_20250912.csv")

print(f"\nDimensiones del los datos: {data.shape}")
print(f"Número de estudiantes: {data.shape[0]:,}")
print(f"Número de variables: {data.shape[1]}")

print(f"\nPeriodo de evaluación: {data['PERIODO'].unique()[0]}")


columnas_interes = [
    "PERIODO",
    "ESTU_GENERO", 
    "FAMI_ESTRATOVIVIENDA",
    "FAMI_EDUCACIONPADRE",
    "FAMI_EDUCACIONMADRE",
    "FAMI_TIENEINTERNET",
    "FAMI_TIENECOMPUTADOR",
    "COLE_NATURALEZA",
    "COLE_BILINGUE"
]

columna_predecir = ["PUNT_GLOBAL"]


faltantes = data[columnas_interes].isnull().mean() * 100
print("Porcentaje de datos faltantes por variable:")
print(faltantes)


columnas_eliminar = ["ESTU_GENERO", "COLE_NATURALEZA"]
data = data.dropna(subset=columnas_eliminar)


columnas_imputar = [
    "FAMI_ESTRATOVIVIENDA",
    "FAMI_EDUCACIONPADRE", 
    "FAMI_EDUCACIONMADRE",
    "FAMI_TIENEINTERNET",
    "FAMI_TIENECOMPUTADOR",
    "COLE_BILINGUE"
]
for col in columnas_imputar:
    if col in data.columns:
        data[col] = data[col].fillna("No reporta") 


print(f"\nVariables seleccionadas para el analisis:")
print("Variables del estudiante y familia:")
for var in ["ESTU_GENERO", "FAMI_ESTRATOVIVIENDA", "FAMI_EDUCACIONPADRE", "FAMI_EDUCACIONMADRE", "FAMI_TIENEINTERNET", "FAMI_TIENECOMPUTADOR"]:
    if var in columnas_interes:
        print(f"- {var}")

print(f"\nVariables del colegio:")
for var in ["COLE_NATURALEZA", "COLE_BILINGUE"]:
    if var in columnas_interes:
        print(f"- {var}")

print(f"\nVariable a predecir: PUNT_GLOBAL")

print(f"\nEstas variables se eligieron porque pueden explicar la desigualdad educativa en Colombia")
print(f"Para manejar los datos faltantes se eliminaron filas con pocos datos faltantes importantes")
print(f"y se imputó 'No reporta' en variables con más datos faltantes para no perder información")
# Out:
# Dimensiones del los datos: (504872, 81)
# Número de estudiantes: 504,872
# Número de variables: 81
#
# Periodo de evaluación: 20204
# Porcentaje de datos faltantes por variable:
# PERIODO                  0.000000
# ESTU_GENERO              0.001585
# FAMI_ESTRATOVIVIENDA     3.357683
# FAMI_EDUCACIONPADRE      2.572929
# FAMI_EDUCACIONMADRE      2.671172
# FAMI_TIENEINTERNET       2.706627
# FAMI_TIENECOMPUTADOR     3.999826
# COLE_NATURALEZA          0.000000
# COLE_BILINGUE           16.441197
# dtype: float64
#
# Variables seleccionadas para el análisis:
# Variables del estudiante y familia:
# - ESTU_GENERO
# - FAMI_ESTRATOVIVIENDA
# - FAMI_EDUCACIONPADRE
# - FAMI_EDUCACIONMADRE
# - FAMI_TIENEINTERNET
# - FAMI_TIENECOMPUTADOR
#
# Variables del colegio:
# - COLE_NATURALEZA
# - COLE_BILINGUE
#
# Variable a predecir: PUNT_GLOBAL
#
# Estas variables se eligieron porque pueden explicar la desigualdad educativa en Colombia
# Para manejar los datos faltantes se eliminaron filas con pocos datos faltantes importantes
# y se imputó 'No reporta' en variables con más datos faltantes para no perder información

# %% [markdown]
# ## Fase 2: identificar características y relaciones en las variables

# %% [markdown]
# En esta fase realizarás análisis descriptivo para identificar posibles patrones o relaciones entre las variables de interés para la problemática planteada. Además, expondrás estadísticas descriptivas y visualizaciones para concluir al respecto de los patrones y las relaciones identificadas. Finalmente, elegirás el segmento de los datos sobre el cual profundizarás con tu análisis (este puede ser, o no, igual al seleccionado anteriormente).

# %% [markdown]
# Pautas generales:
#
# * Calcular estadísticas descriptivas básicas (por lo menos, media/mediana y varianza/desviación) para cada variable sociodemográfica relevante en el contexto del problema.
# * Utilizar librerías especializadas (ej., `matplotlib`, `seaborn`, etc.) para inspeccionar visualmente variables de interés. Los métodos `distplot`, `pairplot`, `boxplot`, o `violinplot`, entre otros, pueden ser útiles.
# * Utilizar el método `groupby` de `pandas`, en conjunto con métodos de visualización, puede proveer evidencia del impacto de las variables sociodemográficas de interés sobre el desempeño de los estudiantes en la prueba.

# %% [markdown]
# Preguntas guía:
#
# * ¿Hay patrones de interés en las distribuciones de las variables o en las relaciones entre ellas?
# * ¿Consideras que existe algún impacto significativo de variables sociodemográficas en los puntajes globales o por área?
# * ¿Sobre cuáles variables harías un análisis más profundo?

# %%
# Implementa tu respuesta en esta celda


print("Analisis descriptivo de la variable principal")
print(data["PUNT_GLOBAL"].describe())

plt.figure(figsize=(4,4))
sns.histplot(data["PUNT_GLOBAL"], bins=30, kde=True)
plt.title("Distribución del Puntaje Global en Saber 11°")
plt.xlabel("Puntaje Global")
plt.ylabel("Frecuencia")
plt.show()


plt.figure(figsize=(6,4))
sns.barplot(x="ESTU_GENERO", y="PUNT_GLOBAL", data=data, estimator="mean")
plt.title("Puntaje Promedio por Género")
plt.xlabel("Género")
plt.ylabel("Puntaje Promedio") 
plt.show()
print("Promedio de puntaje por género:")
print(data.groupby("ESTU_GENERO")["PUNT_GLOBAL"].mean())


if "FAMI_ESTRATOVIVIENDA" in data.columns:
    plt.figure(figsize=(8,5))
    sns.boxplot(x="FAMI_ESTRATOVIVIENDA", y="PUNT_GLOBAL", data=data)
    plt.title("Puntajes por Estrato Socioeconómico")
    plt.xlabel("Estrato")
    plt.ylabel("Puntaje Global")
    plt.xticks(rotation=45)
    plt.show()


if "COLE_NATURALEZA" in data.columns:
    plt.figure(figsize=(6,4))
    sns.barplot(x="COLE_NATURALEZA", y="PUNT_GLOBAL", data=data, estimator="mean")
    plt.title("Puntaje Promedio por Tipo de Colegio")
    plt.xlabel("Tipo de Colegio")
    plt.ylabel("Puntaje Promedio")
    plt.show()
    print("Promedio por tipo de colegio:")
    print(data.groupby("COLE_NATURALEZA")["PUNT_GLOBAL"].mean())


if "FAMI_EDUCACIONPADRE" in data.columns:
    plt.figure(figsize=(10,5))
    sns.boxplot(x="FAMI_EDUCACIONPADRE", y="PUNT_GLOBAL", data=data)
    plt.title("Puntaje Global según Educación del Padre")
    plt.xticks(rotation=45)
    plt.xlabel("Nivel educativo del padre")
    plt.ylabel("Puntaje Global")
    plt.show()

print("\nConclusiones del analisis:")
print("- Hay diferencias en los puntajes según el género del estudiante")
print("- El estrato socioeconómico influye en el desempeño académico")
print("- Los colegios privados tienden a tener mejores puntajes que los públicos")
print("- La educación de los padres también afecta el rendimiento de los estudiantes")
print("- Estos factores muestran la desigualdad educativa en Colombia")
# Out:
# Análisis descriptivo de la variable principal
# count    504864.000000
# mean        248.347020
# std          48.692671
# min           0.000000
# 25%         211.000000
# 50%         245.000000
# 75%         282.000000
# max         500.000000
# Name: PUNT_GLOBAL, dtype: float64
# Promedio de puntaje por género:
# ESTU_GENERO
# F    245.143091
# M    252.228527
# Name: PUNT_GLOBAL, dtype: float64
# Promedio por tipo de colegio:
# COLE_NATURALEZA
# NO OFICIAL    270.839032
# OFICIAL       241.831864
# Name: PUNT_GLOBAL, dtype: float64
# Conclusiones del analisis:
# - Hay diferencias en los puntajes según el género del estudiante
# - El estrato socioeconómico influye en el desempeño académico
# - Los colegios privados tienden a tener mejores puntajes que los públicos
# - La educación de los padres también afecta el rendimiento de los estudiantes
# - Estos factores muestran la desigualdad educativa en Colombia

# %% [markdown]
# ## Fase 3: abordar relación variables-desempeño a través de un modelo

# %% [markdown]
# En esta fase propondrás, implementarás y reportarás el desempeño de uno o más modelos (al menos uno predictivo) que busquen explicar las relaciones entre factores sociodemográficos y el desempeño en la prueba. Además, concluirás con respecto a la validez de al menos un modelo y los posibles hallazgos que se podrían reportar para el *stakeholder*.

# %% [markdown]
# Pautas generales:
#
# * Seleccionar variables y proponer modelos acordes a estas y al contexto del problema.
# * Utilizar librerías especializadas (ej., `statsmodels`, `sklearn`, etc.) para indagar sobre los aspectos que contribuyen al éxito de los estudiantes. Los módulos correspondientes a regresión lineal y regresión logística pueden ser útiles.
# * Asegurar el cumplimiento de los supuestos y buenas prácticas de cada modelo.
# * Utilizar las métricas de evaluación de desempeño (disponibles en las librerías especilizadas), para concluir sobre la validez de los modelos propuestos.

# %% [markdown]
# Preguntas guía:
#
# * ¿Existe algún sub-conjunto de variables socio-demográficas que explique razonablemente bien el desempeño de los estudiantes en la prueba?

# %%
# Implementa tu respuesta en esta celda


from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split


variables_predictoras = [
    "ESTU_GENERO", 
    "FAMI_ESTRATOVIVIENDA", 
    "COLE_NATURALEZA",
    "FAMI_EDUCACIONPADRE",
    "FAMI_EDUCACIONMADRE",
    "FAMI_TIENEINTERNET",
    "FAMI_TIENECOMPUTADOR",
    "COLE_BILINGUE"
]


caracteristicas = data[variables_predictoras]
objetivo = data["PUNT_GLOBAL"]

caracteristicas_numericas = pd.get_dummies(caracteristicas, drop_first=True)

X_entrenamiento, X_prueba, y_entrenamiento, y_prueba = train_test_split(
    caracteristicas_numericas, objetivo, test_size=0.2, random_state=42)

regresion = LinearRegression()
regresion.fit(X_entrenamiento, y_entrenamiento)

predicciones = regresion.predict(X_prueba)

coeficiente_r2 = r2_score(y_prueba, predicciones)

print("RESULTADOS DEL MODELO PREDICTIVO")
print(f"Coeficiente R²: {coeficiente_r2:.3f}")
print(f"El modelo explica el {coeficiente_r2*100:.1f}% de la variabilidad en los puntajes")
print("\nEsto indica que los factores sociodemográficos tienen un impacto")
print("significativo en el desempeño académico de los estudiantes.")
# Out:
# RESULTADOS DEL MODELO PREDICTIVO
# Coeficiente R²: 0.226
# El modelo explica el 22.6% de la variabilidad en los puntajes
#
# Esto indica que los factores sociodemográficos tienen un impacto
# significativo en el desempeño académico de los estudiantes.

# %% [markdown]
# ## Fase 4

# %% [markdown]
# Deberás elegir y realizar una de las dos alternativas que se encuentran a continuación.

# %% [markdown]
# ### Alternativa 1: desarrollar una herramienta interactiva de análisis

# %% [markdown]
# En esta fase desarrollarás, a partir de alguno de los análisis realizados, una herramienta interactiva que sea relevante en el contexto del problema, acompañada de las instrucciones necesarias para que un usuario la pueda utilizar.

# %% [markdown]
# Pautas generales:
#
# * Seleccionar uno de los análisis previos que pueda verse enriquecido con alguna característica de interactividad.
# * Seleccionar el/los parámetro(s) que el usuario podrá cambiar.
# * Desarrollar las funciones que se deben ejecutar con cada acción del usuario.
# * Utilizar una librería especializada (ej., `ipywidgets`, `panel`, etc.) para implementar la herramienta.

# %% [markdown]
# Preguntas guía:
#
# * ¿Cuál o cuáles preguntas podrá hacerle el usuario a la herramienta y cómo aporta la respuesta al análisis?
# * ¿Qué aprendizajes clave puede explorar u obtener el usuario con esta herramienta?

# %%
# Implementa tu respuesta en esta celda}

# %% [markdown]
# ### Alternativa 2: registrar en bases de datos relacionales con PySpark

# %% [markdown]
# En esta fase desarrollarás, a partir de alguno de los análisis realizados, un _script_ que sea relevante en el contexto del problema, acompañado de las instrucciones necesarias para que un usuario lo pueda ejecutar.

# %% [markdown]
# Pautas generales:
#
# * Cargar en una base de datos relacional (tipo SQL) el segmento de los datos sobre el cual profundizaste en tu anális, utilizando una tabla distinta para cada categoría de campos. Por ejemplo, una categoría puedes ser información del colegio; en cuyo caso, una tabla debería contener un registro único para cada colegio y todos los campos asociados.
#
# * Los campos, a excepción de los identificadores, deben existir en un única tabla.
#
# * Cada registro debe existir una única vez en su respectiva tabla.
#
# * Cada registro debe tener un identificador único en su tabla, el cual establece una relación entre tablas.
#
# * Seleccionar uno de los modelos predictivos implementados.
#
# * Crear en la base de datos relacional una tabla que contenga únicamente los identificadores del registro y la predicción de la variable de respuesta hecha por el modelo.
#
# * Desarrollar _queries_ de SQL según las siguientes indicaciones y concluir acerca de los resultados:
#     * Un _query_ que seleccione todos registros y los agregue en una única tabla. Para esto debes relacionar las tablas por su identificador, utilizando el método `JOIN`.
#     * Un _query_ que contenga el puntaje promedio de los estudiantes, agrupado por año y por colegio.
#     * Distintos _queries_ que calculen medidas de error de predicción del modelo a partir de los datos reales y las predicciones respectivas. Debes reportar el error para cada registro, el error total de los registros de entrenamiento y el error total de los registros de prueba.
#     * Haz dos _queries_ adicionales que resulten interesantes.

# %% [markdown]
# Preguntas guía:
#
# * ¿Cómo aporta la segmentación de los datos en categorías de campos al manejo de los datos?
# * ¿Qué filtros y agrupaciones podemos aplicar sobre los datos con el fin de obtener información relevante?

# %%
# Implementa tu respuesta en esta celda

# %% [markdown]
# ## Referencias

# %% [markdown]
# *  J. VanderPlas (2016) *Python Data Science Handbook: Essential Tools for Working with Data* O'Reilly Media, Inc.
# *  scikit-learn developers . (2020). Demo of DBSCAN clustering algorithm. 11 Diciembre 2020, de scikit-learn <br> https://scikit-learn.org/stable/auto_examples/cluster/plot_dbscan.html#sphx-glr-auto-examples-cluster-plot-dbscan-py

# %% [markdown]
# ## Créditos

# %% [markdown]
# __Autores__: Camilo Hernando Gómez Castro, Alejandro Mantilla Redondo, Jose Fernando Barrera de Plaza, Diego Alejandro Cely Gómez.
#
# __Fecha última actualización__: 29/09/2022
